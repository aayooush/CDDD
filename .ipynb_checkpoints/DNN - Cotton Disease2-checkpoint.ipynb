# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# <ipython-input-1-d5df0069828e> in <module>()
# ----> 1 from google.colab import drive
#       2 drive.mount('/content/drive')
#
# ModuleNotFoundError: No module named 'google.colab'

# %%
#CROPP CODE FOR IMAGE TRAINING
import matplotlib.pyplot as plt
import cv2
import numpy as np
import os
# %matplotlib inline
import tensorflow as tf
#np.set_printoptions(threshold=np.inf)
from tensorflow import estimator
tf.reset_default_graph()
from sklearn.model_selection import train_test_split
gs = 0
N_CLASSES = 4   
IMG_W = 200      # for better visibility, go with >180
IMG_H = 200
learning_rate = 0.0001     #slow learning rate for better learning
MODEL = './DNN_Model'
NUM_EPOCH = 50
BATCH_SIZE = 16
LOOP = 16                # total no. of epoch = loop * 2*num_epoch
disease ={0:'Healthy', 
          1:'Mosaic_Virus', 
          2:'rust', 
          3:'woolyaphids'}       
def normalize(df):    
    return (df - df.min()) / (df.max() - df.min())
def denormalize(df,norm_data):    
    return (norm_data * (df.max() - df.min())) + df.min()

# %%
def getdata(path):
    ''' returns shuffled array of image file path and labels of corresponding file '''
    woolyaphids = []
    woolyaphids_l= []
    Healthy = []
    Healthy_l = []
    Mosaic_Virus = []
    Mosaic_Virus_l = []
    rust = []
    rust_l = []
    for file in os.listdir(path):
        name=file.split(sep='.')
        if 'healthy' in name[0]:
            Healthy.append(path+file)
            Healthy_l.append(0)
        elif 'Mosaic_Virus' in name[0]:
            Mosaic_Virus.append(path+file)
            Mosaic_Virus_l.append(1)
        elif 'mosaic_virus' in name[0]:
            Mosaic_Virus.append(path+file)
            Mosaic_Virus_l.append(1)
        elif 'rust' in name[0]:
            rust.append(path+file)
            rust_l.append(2)
        elif 'Woolyaphids' in name[0]:
            woolyaphids.append(path+file)
            woolyaphids_l.append(3)
        elif 'woolyaphids' in name[0]:
            woolyaphids.append(path+file)
            woolyaphids_l.append(3)
            
    image_list = np.hstack((Healthy, Mosaic_Virus, rust, woolyaphids ))
    label_list = np.hstack(( Healthy_l, Mosaic_Virus_l, rust_l, woolyaphids_l))
    temp = np.array([image_list, label_list])
    temp = temp.transpose()
    #shuffle whole files and labels respectively
    np.random.shuffle(temp)
    image_list = list(temp[:, 0])
    label_list = list(temp[:, 1])
    label_list = [int(i) for i in label_list]
    print("Healthy plant is: ", len(Healthy))
    print("Rust disease plant is: ", len(rust))
    print("Mosaic_Virus plant is: ", len(Mosaic_Virus))
    print("Woolyaphids plant is: ", len(Mosaic_Virus))
    return image_list, label_list

def process(path):
    '''this function takes file paths from getdata function, 
it reads and processes image file in 4D tensor format i.e.
[batch_size, IMG_Width, IMG_Height, channel]   for grayscale channel = 1, for RGB, channel = 3
'''
    a, train_labels = getdata(path)
    img = []
    batch=len(a)
    for i in range(batch):
        im = cv2.imread(a[i], cv2.IMREAD_COLOR) 
        b,g,r = cv2.split(im)
        image = cv2.merge([r,g,b])
        res = cv2.resize(image,(IMG_W, IMG_H), interpolation = cv2.INTER_CUBIC)
        img.append(res)
        if i%50 == 0: print('Processed {} of {}'.format(i, batch))
    print("finished\nCount of Images is ",len(img),"with input shape",res.shape)
    return np.array(img, dtype=np.int32), np.array(train_labels[:batch], dtype = np.int32)

# %%
import os
path = os.path.abspath("DNN_New_Data")
path = path+'\\'
# path
X, Y = process(path)
# Out:
# Healthy plant is:  155
# Rust disease plant is:  136
# Mosaic_Virus plant is:  151
# Woolyaphids plant is:  151
# Processed 0 of 592
# Processed 50 of 592
# Processed 100 of 592
# Processed 150 of 592
# Processed 200 of 592
# Processed 250 of 592
# Processed 300 of 592
# Processed 350 of 592
# Processed 400 of 592
# Processed 450 of 592
# Processed 500 of 592
# Processed 550 of 592
# finished
# Count of Images is  592 with input shape (200, 200, 3)

# %%
data = []
for i in X:
    data.append(i.reshape(IMG_W*IMG_H*3))
data = np.array(data)

# %%
print('shape of whole data and their labels are as follows',data.shape,'and',Y.shape,"respectively")
# Out:
# shape of whole data and their labels are as follows (592, 120000) and (592,) respectively

# %%
for i in range(170, 180):
    j =data[i].reshape(IMG_W,IMG_H,3)
    print("actually it is:",disease[Y[i]])
    plt.imshow(j)
    plt.show()  
#this cell is used to ensure proper labelling of image
# Out:
# actually it is: Mosaic_Virus
# actually it is: woolyaphids
# actually it is: rust
# actually it is: Healthy
# actually it is: Healthy
# actually it is: rust
# actually it is: Healthy
# actually it is: woolyaphids
# actually it is: woolyaphids
# actually it is: Healthy

# %%
X_train, X_val, Y_train, Y_val = train_test_split(data ,Y, test_size=0.3, random_state=1)

# %%
X_tr = []
for i in X_train:
    X_tr.append(normalize(i))
X_tr = np.array(X_tr)

X_v = []
for i in X_val:
    X_v.append(normalize(i))
X_v = np.array(X_v)

# %%
feat_cols=[tf.feature_column.numeric_column('x', shape=[IMG_H*IMG_W*3])]

# %%
deep_model = tf.estimator.DNNClassifier(feature_columns=feat_cols, 
                                      n_classes=N_CLASSES,
                                      hidden_units=[100, 100, 100, 100, 100,50], 
                                      activation_fn=tf.nn.leaky_relu,
                                      optimizer=tf.train.GradientDescentOptimizer(learning_rate),
                                      model_dir=MODEL)
# Out:
# INFO:tensorflow:Using default config.
# INFO:tensorflow:Using config: {'_model_dir': './model7', '_tf_random_seed': None, '_save_summary_steps': 100, '_save_checkpoints_steps': None, '_save_checkpoints_secs': 600, '_session_config': allow_soft_placement: true
# graph_options {
#   rewrite_options {
#     meta_optimizer_iterations: ONE
#   }
# }
# , '_keep_checkpoint_max': 5, '_keep_checkpoint_every_n_hours': 10000, '_log_step_count_steps': 100, '_train_distribute': None, '_device_fn': None, '_protocol': None, '_eval_distribute': None, '_experimental_distribute': None, '_service': None, '_cluster_spec': <tensorflow.python.training.server_lib.ClusterSpec object at 0x0000020E045064A8>, '_task_type': 'worker', '_task_id': 0, '_global_id_in_cluster': 0, '_master': '', '_evaluation_master': '', '_is_chief': True, '_num_ps_replicas': 0, '_num_worker_replicas': 1}

# %%
input_fn = estimator.inputs.numpy_input_fn(x={'x':np.array(X_tr)}, 
                                           y=np.array(Y_train),
                                           shuffle= True,
                                           num_epochs=NUM_EPOCH,
                                           batch_size=BATCH_SIZE)

# %%
input_fn_eval = estimator.inputs.numpy_input_fn(x = {'x':np.array(X_v)},
                                                y = Y_val,
                                                shuffle=False)

# %%
for i in range(LOOP):
    gs = gs + NUM_EPOCH*2
    train_spec = tf.estimator.TrainSpec(input_fn = input_fn, max_steps = gs)
    eval_spec  = tf.estimator.EvalSpec(input_fn = input_fn_eval)
    tf.estimator.train_and_evaluate(deep_model, train_spec, eval_spec)
    print("*************************************************************************************** step = ", i)
# Out:
# INFO:tensorflow:Running training and evaluation locally (non-distributed).
# INFO:tensorflow:Start train and evaluate loop. The evaluate will happen after every checkpoint. Checkpoint frequency is determined based on RunConfig arguments: save_checkpoints_steps None or save_checkpoints_secs 600.
# WARNING:tensorflow:From C:\Users\NitishTalekar\Applictions\Anaconda3\lib\site-packages\tensorflow\python\estimator\inputs\queues\feeding_queue_runner.py:62: QueueRunner.__init__ (from tensorflow.python.training.queue_runner_impl) is deprecated and will be removed in a future version.
# Instructions for updating:
# To construct input pipelines, use the `tf.data` module.
# WARNING:tensorflow:From C:\Users\NitishTalekar\Applictions\Anaconda3\lib\site-packages\tensorflow\python\estimator\inputs\queues\feeding_functions.py:500: add_queue_runner (from tensorflow.python.training.queue_runner_impl) is deprecated and will be removed in a future version.
# Instructions for updating:
# To construct input pipelines, use the `tf.data` module.
# INFO:tensorflow:Calling model_fn.
# INFO:tensorflow:Done calling model_fn.
# INFO:tensorflow:Create CheckpointSaverHook.
# INFO:tensorflow:Graph was finalized.
# INFO:tensorflow:Running local_init_op.
# INFO:tensorflow:Done running local_init_op.
# WARNING:tensorflow:From C:\Users\NitishTalekar\Applictions\Anaconda3\lib\site-packages\tensorflow\python\training\monitored_session.py:804: start_queue_runners (from tensorflow.python.training.queue_runner_impl) is deprecated and will be removed in a future version.
# Instructions for updating:
# To construct input pipelines, use the `tf.data` module.
# INFO:tensorflow:Saving checkpoints for 0 into ./model7\model.ckpt.
# INFO:tensorflow:loss = 22.003948, step = 1
# INFO:tensorflow:Saving checkpoints for 100 into ./model7\model.ckpt.
# INFO:tensorflow:Calling model_fn.
# INFO:tensorflow:Done calling model_fn.
# INFO:tensorflow:Starting evaluation at 2019-10-31-14:12:44
# INFO:tensorflow:Graph was finalized.
# INFO:tensorflow:Restoring parameters from ./model7\model.ckpt-100
# INFO:tensorflow:Running local_init_op.
# INFO:tensorflow:Done running local_init_op.
# INFO:tensorflow:Finished evaluation at 2019-10-31-14:12:44
# INFO:tensorflow:Saving dict for global step 100: accuracy = 0.7022472, average_loss = 1.1659977, global_step = 100, loss = 103.773796
# INFO:tensorflow:Saving 'checkpoint_path' summary for global step 100: ./model7\model.ckpt-100
# INFO:tensorflow:Loss for final step: 19.645359.
# *************************************************************************************** step =  0
# INFO:tensorflow:Running training and evaluation locally (non-distributed).
# INFO:tensorflow:Start train and evaluate loop. The evaluate will happen after every checkpoint. Checkpoint frequency is determined based on RunConfig arguments: save_checkpoints_steps None or save_checkpoints_secs 600.
# INFO:tensorflow:Calling model_fn.
# INFO:tensorflow:Done calling model_fn.
# INFO:tensorflow:Create CheckpointSaverHook.
# INFO:tensorflow:Graph was finalized.
# INFO:tensorflow:Restoring parameters from ./model7\model.ckpt-100
# INFO:tensorflow:Running local_init_op.
# INFO:tensorflow:Done running local_init_op.
# INFO:tensorflow:Saving checkpoints for 100 into ./model7\model.ckpt.
# INFO:tensorflow:loss = 18.396912, step = 101
# INFO:tensorflow:Saving checkpoints for 200 into ./model7\model.ckpt.
# INFO:tensorflow:Calling model_fn.
# INFO:tensorflow:Done calling model_fn.
# INFO:tensorflow:Starting evaluation at 2019-10-31-14:12:58
# INFO:tensorflow:Graph was finalized.
# INFO:tensorflow:Restoring parameters from ./model7\model.ckpt-200
# INFO:tensorflow:Running local_init_op.
# INFO:tensorflow:Done running local_init_op.
# INFO:tensorflow:Finished evaluation at 2019-10-31-14:12:59
# INFO:tensorflow:Saving dict for global step 200: accuracy = 0.6011236, average_loss = 0.937176, global_step = 200, loss = 83.40866
# INFO:tensorflow:Saving 'checkpoint_path' summary for global step 200: ./model7\model.ckpt-200
# INFO:tensorflow:Loss for final step: 12.96667.
# *************************************************************************************** step =  1
# INFO:tensorflow:Running training and evaluation locally (non-distributed).
# INFO:tensorflow:Start train and evaluate loop. The evaluate will happen after every checkpoint. Checkpoint frequency is determined based on RunConfig arguments: save_checkpoints_steps None or save_checkpoints_secs 600.
# INFO:tensorflow:Calling model_fn.
# INFO:tensorflow:Done calling model_fn.
# INFO:tensorflow:Create CheckpointSaverHook.
# INFO:tensorflow:Graph was finalized.
# INFO:tensorflow:Restoring parameters from ./model7\model.ckpt-200
# INFO:tensorflow:Running local_init_op.
# INFO:tensorflow:Done running local_init_op.
# INFO:tensorflow:Saving checkpoints for 200 into ./model7\model.ckpt.
# INFO:tensorflow:loss = 12.115195, step = 201
# INFO:tensorflow:Saving checkpoints for 300 into ./model7\model.ckpt.
# INFO:tensorflow:Calling model_fn.
# INFO:tensorflow:Done calling model_fn.
# INFO:tensorflow:Starting evaluation at 2019-10-31-14:13:12
# INFO:tensorflow:Graph was finalized.
# INFO:tensorflow:Restoring parameters from ./model7\model.ckpt-300
# INFO:tensorflow:Running local_init_op.
# INFO:tensorflow:Done running local_init_op.
# INFO:tensorflow:Finished evaluation at 2019-10-31-14:13:13
# INFO:tensorflow:Saving dict for global step 300: accuracy = 0.75842696, average_loss = 0.6737428, global_step = 300, loss = 59.963108
# INFO:tensorflow:Saving 'checkpoint_path' summary for global step 300: ./model7\model.ckpt-300
# INFO:tensorflow:Loss for final step: 5.969577.
# *************************************************************************************** step =  2
# INFO:tensorflow:Running training and evaluation locally (non-distributed).
# INFO:tensorflow:Start train and evaluate loop. The evaluate will happen after every checkpoint. Checkpoint frequency is determined based on RunConfig arguments: save_checkpoints_steps None or save_checkpoints_secs 600.
# INFO:tensorflow:Calling model_fn.
# INFO:tensorflow:Done calling model_fn.
# INFO:tensorflow:Create CheckpointSaverHook.
# INFO:tensorflow:Graph was finalized.
# INFO:tensorflow:Restoring parameters from ./model7\model.ckpt-300
# INFO:tensorflow:Running local_init_op.
# INFO:tensorflow:Done running local_init_op.
# INFO:tensorflow:Saving checkpoints for 300 into ./model7\model.ckpt.
# INFO:tensorflow:loss = 13.114009, step = 301
# INFO:tensorflow:Saving checkpoints for 400 into ./model7\model.ckpt.
# INFO:tensorflow:Calling model_fn.
# INFO:tensorflow:Done calling model_fn.
# INFO:tensorflow:Starting evaluation at 2019-10-31-14:13:26
# INFO:tensorflow:Graph was finalized.
# INFO:tensorflow:Restoring parameters from ./model7\model.ckpt-400
# INFO:tensorflow:Running local_init_op.
# INFO:tensorflow:Done running local_init_op.
# INFO:tensorflow:Finished evaluation at 2019-10-31-14:13:27
# INFO:tensorflow:Saving dict for global step 400: accuracy = 0.66292137, average_loss = 0.8493918, global_step = 400, loss = 75.59587
# INFO:tensorflow:Saving 'checkpoint_path' summary for global step 400: ./model7\model.ckpt-400
# INFO:tensorflow:Loss for final step: 8.286722.
# *************************************************************************************** step =  3
# INFO:tensorflow:Running training and evaluation locally (non-distributed).
# INFO:tensorflow:Start train and evaluate loop. The evaluate will happen after every checkpoint. Checkpoint frequency is determined based on RunConfig arguments: save_checkpoints_steps None or save_checkpoints_secs 600.
# INFO:tensorflow:Calling model_fn.
# INFO:tensorflow:Done calling model_fn.
# INFO:tensorflow:Create CheckpointSaverHook.
# INFO:tensorflow:Graph was finalized.
# INFO:tensorflow:Restoring parameters from ./model7\model.ckpt-400
# INFO:tensorflow:Running local_init_op.
# INFO:tensorflow:Done running local_init_op.
# INFO:tensorflow:Saving checkpoints for 400 into ./model7\model.ckpt.
# INFO:tensorflow:loss = 17.405376, step = 401
# INFO:tensorflow:Saving checkpoints for 500 into ./model7\model.ckpt.
# INFO:tensorflow:Calling model_fn.
# INFO:tensorflow:Done calling model_fn.
# INFO:tensorflow:Starting evaluation at 2019-10-31-14:13:39
# INFO:tensorflow:Graph was finalized.
# INFO:tensorflow:Restoring parameters from ./model7\model.ckpt-500
# INFO:tensorflow:Running local_init_op.
# INFO:tensorflow:Done running local_init_op.
# INFO:tensorflow:Finished evaluation at 2019-10-31-14:13:40
# INFO:tensorflow:Saving dict for global step 500: accuracy = 0.8426966, average_loss = 0.44772518, global_step = 500, loss = 39.84754
# INFO:tensorflow:Saving 'checkpoint_path' summary for global step 500: ./model7\model.ckpt-500
# INFO:tensorflow:Loss for final step: 3.3800888.
# *************************************************************************************** step =  4
# INFO:tensorflow:Running training and evaluation locally (non-distributed).
# INFO:tensorflow:Start train and evaluate loop. The evaluate will happen after every checkpoint. Checkpoint frequency is determined based on RunConfig arguments: save_checkpoints_steps None or save_checkpoints_secs 600.
# INFO:tensorflow:Calling model_fn.
# INFO:tensorflow:Done calling model_fn.
# INFO:tensorflow:Create CheckpointSaverHook.
# INFO:tensorflow:Graph was finalized.
# INFO:tensorflow:Restoring parameters from ./model7\model.ckpt-500
# INFO:tensorflow:Running local_init_op.
# INFO:tensorflow:Done running local_init_op.
# INFO:tensorflow:Saving checkpoints for 500 into ./model7\model.ckpt.
# INFO:tensorflow:loss = 5.7585435, step = 501
# INFO:tensorflow:Saving checkpoints for 600 into ./model7\model.ckpt.
# INFO:tensorflow:Calling model_fn.
# INFO:tensorflow:Done calling model_fn.
# INFO:tensorflow:Starting evaluation at 2019-10-31-14:13:53
# INFO:tensorflow:Graph was finalized.
# INFO:tensorflow:Restoring parameters from ./model7\model.ckpt-600
# INFO:tensorflow:Running local_init_op.
# INFO:tensorflow:Done running local_init_op.
# INFO:tensorflow:Finished evaluation at 2019-10-31-14:13:54
# INFO:tensorflow:Saving dict for global step 600: accuracy = 0.66292137, average_loss = 0.86590165, global_step = 600, loss = 77.06525
# INFO:tensorflow:Saving 'checkpoint_path' summary for global step 600: ./model7\model.ckpt-600
# INFO:tensorflow:Loss for final step: 6.3031816.
# *************************************************************************************** step =  5
# INFO:tensorflow:Running training and evaluation locally (non-distributed).
# INFO:tensorflow:Start train and evaluate loop. The evaluate will happen after every checkpoint. Checkpoint frequency is determined based on RunConfig arguments: save_checkpoints_steps None or save_checkpoints_secs 600.
# INFO:tensorflow:Calling model_fn.
# INFO:tensorflow:Done calling model_fn.
# INFO:tensorflow:Create CheckpointSaverHook.
# INFO:tensorflow:Graph was finalized.
# INFO:tensorflow:Restoring parameters from ./model7\model.ckpt-600
# INFO:tensorflow:Running local_init_op.
# INFO:tensorflow:Done running local_init_op.
# INFO:tensorflow:Saving checkpoints for 600 into ./model7\model.ckpt.
# INFO:tensorflow:loss = 8.422784, step = 601
# INFO:tensorflow:Saving checkpoints for 700 into ./model7\model.ckpt.
# INFO:tensorflow:Calling model_fn.
# INFO:tensorflow:Done calling model_fn.
# INFO:tensorflow:Starting evaluation at 2019-10-31-14:14:07
# INFO:tensorflow:Graph was finalized.
# INFO:tensorflow:Restoring parameters from ./model7\model.ckpt-700
# INFO:tensorflow:Running local_init_op.
# INFO:tensorflow:Done running local_init_op.
# INFO:tensorflow:Finished evaluation at 2019-10-31-14:14:08
# INFO:tensorflow:Saving dict for global step 700: accuracy = 0.9044944, average_loss = 0.3418467, global_step = 700, loss = 30.424356
# INFO:tensorflow:Saving 'checkpoint_path' summary for global step 700: ./model7\model.ckpt-700
# INFO:tensorflow:Loss for final step: 4.109091.
# *************************************************************************************** step =  6
# INFO:tensorflow:Running training and evaluation locally (non-distributed).
# INFO:tensorflow:Start train and evaluate loop. The evaluate will happen after every checkpoint. Checkpoint frequency is determined based on RunConfig arguments: save_checkpoints_steps None or save_checkpoints_secs 600.
# INFO:tensorflow:Calling model_fn.
# INFO:tensorflow:Done calling model_fn.
# INFO:tensorflow:Create CheckpointSaverHook.
# INFO:tensorflow:Graph was finalized.
# INFO:tensorflow:Restoring parameters from ./model7\model.ckpt-700
# INFO:tensorflow:Running local_init_op.
# INFO:tensorflow:Done running local_init_op.
# INFO:tensorflow:Saving checkpoints for 700 into ./model7\model.ckpt.
# INFO:tensorflow:loss = 1.6993594, step = 701
# INFO:tensorflow:Saving checkpoints for 800 into ./model7\model.ckpt.
# INFO:tensorflow:Calling model_fn.
# INFO:tensorflow:Done calling model_fn.
# INFO:tensorflow:Starting evaluation at 2019-10-31-14:14:21
# INFO:tensorflow:Graph was finalized.
# INFO:tensorflow:Restoring parameters from ./model7\model.ckpt-800
# INFO:tensorflow:Running local_init_op.
# INFO:tensorflow:Done running local_init_op.
# INFO:tensorflow:Finished evaluation at 2019-10-31-14:14:22
# INFO:tensorflow:Saving dict for global step 800: accuracy = 0.8820225, average_loss = 0.29459772, global_step = 800, loss = 26.219196
# INFO:tensorflow:Saving 'checkpoint_path' summary for global step 800: ./model7\model.ckpt-800
# INFO:tensorflow:Loss for final step: 0.86052155.
# *************************************************************************************** step =  7
# INFO:tensorflow:Running training and evaluation locally (non-distributed).
# INFO:tensorflow:Start train and evaluate loop. The evaluate will happen after every checkpoint. Checkpoint frequency is determined based on RunConfig arguments: save_checkpoints_steps None or save_checkpoints_secs 600.
# INFO:tensorflow:Calling model_fn.
# INFO:tensorflow:Done calling model_fn.
# INFO:tensorflow:Create CheckpointSaverHook.
# INFO:tensorflow:Graph was finalized.
# INFO:tensorflow:Restoring parameters from ./model7\model.ckpt-800
# INFO:tensorflow:Running local_init_op.
# INFO:tensorflow:Done running local_init_op.
# INFO:tensorflow:Saving checkpoints for 800 into ./model7\model.ckpt.
# INFO:tensorflow:loss = 1.5037959, step = 801
# INFO:tensorflow:Saving checkpoints for 900 into ./model7\model.ckpt.
# INFO:tensorflow:Calling model_fn.
# INFO:tensorflow:Done calling model_fn.
# INFO:tensorflow:Starting evaluation at 2019-10-31-14:14:35
# INFO:tensorflow:Graph was finalized.
# INFO:tensorflow:Restoring parameters from ./model7\model.ckpt-900
# INFO:tensorflow:Running local_init_op.
# INFO:tensorflow:Done running local_init_op.
# INFO:tensorflow:Finished evaluation at 2019-10-31-14:14:36
# INFO:tensorflow:Saving dict for global step 900: accuracy = 0.8820225, average_loss = 0.30030897, global_step = 900, loss = 26.727499
# INFO:tensorflow:Saving 'checkpoint_path' summary for global step 900: ./model7\model.ckpt-900
# INFO:tensorflow:Loss for final step: 1.4541154.
# *************************************************************************************** step =  8
# INFO:tensorflow:Running training and evaluation locally (non-distributed).
# INFO:tensorflow:Start train and evaluate loop. The evaluate will happen after every checkpoint. Checkpoint frequency is determined based on RunConfig arguments: save_checkpoints_steps None or save_checkpoints_secs 600.
# INFO:tensorflow:Calling model_fn.
# INFO:tensorflow:Done calling model_fn.
# INFO:tensorflow:Create CheckpointSaverHook.
# INFO:tensorflow:Graph was finalized.
# INFO:tensorflow:Restoring parameters from ./model7\model.ckpt-900
# INFO:tensorflow:Running local_init_op.
# INFO:tensorflow:Done running local_init_op.
# INFO:tensorflow:Saving checkpoints for 900 into ./model7\model.ckpt.
# INFO:tensorflow:loss = 2.1403651, step = 901
# INFO:tensorflow:Saving checkpoints for 1000 into ./model7\model.ckpt.
# INFO:tensorflow:Calling model_fn.
# INFO:tensorflow:Done calling model_fn.
# INFO:tensorflow:Starting evaluation at 2019-10-31-14:14:48
# INFO:tensorflow:Graph was finalized.
# INFO:tensorflow:Restoring parameters from ./model7\model.ckpt-1000
# INFO:tensorflow:Running local_init_op.
# INFO:tensorflow:Done running local_init_op.
# INFO:tensorflow:Finished evaluation at 2019-10-31-14:14:49
# INFO:tensorflow:Saving dict for global step 1000: accuracy = 0.83146065, average_loss = 0.39170316, global_step = 1000, loss = 34.86158
# INFO:tensorflow:Saving 'checkpoint_path' summary for global step 1000: ./model7\model.ckpt-1000
# INFO:tensorflow:Loss for final step: 2.0914423.
# *************************************************************************************** step =  9
# INFO:tensorflow:Running training and evaluation locally (non-distributed).
# INFO:tensorflow:Start train and evaluate loop. The evaluate will happen after every checkpoint. Checkpoint frequency is determined based on RunConfig arguments: save_checkpoints_steps None or save_checkpoints_secs 600.
# INFO:tensorflow:Calling model_fn.
# INFO:tensorflow:Done calling model_fn.
# INFO:tensorflow:Create CheckpointSaverHook.
# INFO:tensorflow:Graph was finalized.
# INFO:tensorflow:Restoring parameters from ./model7\model.ckpt-1000
# INFO:tensorflow:Running local_init_op.
# INFO:tensorflow:Done running local_init_op.
# INFO:tensorflow:Saving checkpoints for 1000 into ./model7\model.ckpt.
# INFO:tensorflow:loss = 4.263921, step = 1001
# INFO:tensorflow:Saving checkpoints for 1100 into ./model7\model.ckpt.
# INFO:tensorflow:Calling model_fn.
# INFO:tensorflow:Done calling model_fn.
# INFO:tensorflow:Starting evaluation at 2019-10-31-14:15:02
# INFO:tensorflow:Graph was finalized.
# INFO:tensorflow:Restoring parameters from ./model7\model.ckpt-1100
# INFO:tensorflow:Running local_init_op.
# INFO:tensorflow:Done running local_init_op.
# INFO:tensorflow:Finished evaluation at 2019-10-31-14:15:03
# INFO:tensorflow:Saving dict for global step 1100: accuracy = 0.89325845, average_loss = 0.29496753, global_step = 1100, loss = 26.25211
# INFO:tensorflow:Saving 'checkpoint_path' summary for global step 1100: ./model7\model.ckpt-1100
# INFO:tensorflow:Loss for final step: 0.7126235.
# *************************************************************************************** step =  10
# INFO:tensorflow:Running training and evaluation locally (non-distributed).
# INFO:tensorflow:Start train and evaluate loop. The evaluate will happen after every checkpoint. Checkpoint frequency is determined based on RunConfig arguments: save_checkpoints_steps None or save_checkpoints_secs 600.
# INFO:tensorflow:Calling model_fn.
# INFO:tensorflow:Done calling model_fn.
# INFO:tensorflow:Create CheckpointSaverHook.
# INFO:tensorflow:Graph was finalized.
# INFO:tensorflow:Restoring parameters from ./model7\model.ckpt-1100
# INFO:tensorflow:Running local_init_op.
# INFO:tensorflow:Done running local_init_op.
# INFO:tensorflow:Saving checkpoints for 1100 into ./model7\model.ckpt.
# INFO:tensorflow:loss = 2.4854133, step = 1101
# INFO:tensorflow:Saving checkpoints for 1200 into ./model7\model.ckpt.
# INFO:tensorflow:Calling model_fn.
# INFO:tensorflow:Done calling model_fn.
# INFO:tensorflow:Starting evaluation at 2019-10-31-14:15:16
# INFO:tensorflow:Graph was finalized.
# INFO:tensorflow:Restoring parameters from ./model7\model.ckpt-1200
# INFO:tensorflow:Running local_init_op.
# INFO:tensorflow:Done running local_init_op.
# INFO:tensorflow:Finished evaluation at 2019-10-31-14:15:16
# INFO:tensorflow:Saving dict for global step 1200: accuracy = 0.89325845, average_loss = 0.2997828, global_step = 1200, loss = 26.68067
# INFO:tensorflow:Saving 'checkpoint_path' summary for global step 1200: ./model7\model.ckpt-1200
# INFO:tensorflow:Loss for final step: 1.9144878.
# *************************************************************************************** step =  11
# INFO:tensorflow:Running training and evaluation locally (non-distributed).
# INFO:tensorflow:Start train and evaluate loop. The evaluate will happen after every checkpoint. Checkpoint frequency is determined based on RunConfig arguments: save_checkpoints_steps None or save_checkpoints_secs 600.
# INFO:tensorflow:Calling model_fn.
# INFO:tensorflow:Done calling model_fn.
# INFO:tensorflow:Create CheckpointSaverHook.
# INFO:tensorflow:Graph was finalized.
# INFO:tensorflow:Restoring parameters from ./model7\model.ckpt-1200
# INFO:tensorflow:Running local_init_op.
# INFO:tensorflow:Done running local_init_op.
# INFO:tensorflow:Saving checkpoints for 1200 into ./model7\model.ckpt.
# INFO:tensorflow:loss = 3.5472078, step = 1201
# INFO:tensorflow:Saving checkpoints for 1300 into ./model7\model.ckpt.
# INFO:tensorflow:Calling model_fn.
# INFO:tensorflow:Done calling model_fn.
# INFO:tensorflow:Starting evaluation at 2019-10-31-14:15:29
# INFO:tensorflow:Graph was finalized.
# INFO:tensorflow:Restoring parameters from ./model7\model.ckpt-1300
# INFO:tensorflow:Running local_init_op.
# INFO:tensorflow:Done running local_init_op.
# INFO:tensorflow:Finished evaluation at 2019-10-31-14:15:30
# INFO:tensorflow:Saving dict for global step 1300: accuracy = 0.9044944, average_loss = 0.24269925, global_step = 1300, loss = 21.600233
# INFO:tensorflow:Saving 'checkpoint_path' summary for global step 1300: ./model7\model.ckpt-1300
# INFO:tensorflow:Loss for final step: 0.589309.
# *************************************************************************************** step =  12
# INFO:tensorflow:Running training and evaluation locally (non-distributed).
# INFO:tensorflow:Start train and evaluate loop. The evaluate will happen after every checkpoint. Checkpoint frequency is determined based on RunConfig arguments: save_checkpoints_steps None or save_checkpoints_secs 600.
# INFO:tensorflow:Calling model_fn.
# INFO:tensorflow:Done calling model_fn.
# INFO:tensorflow:Create CheckpointSaverHook.
# INFO:tensorflow:Graph was finalized.
# INFO:tensorflow:Restoring parameters from ./model7\model.ckpt-1300
# INFO:tensorflow:Running local_init_op.
# INFO:tensorflow:Done running local_init_op.
# INFO:tensorflow:Saving checkpoints for 1300 into ./model7\model.ckpt.
# INFO:tensorflow:loss = 0.47418526, step = 1301
# INFO:tensorflow:Saving checkpoints for 1400 into ./model7\model.ckpt.
# INFO:tensorflow:Calling model_fn.
# INFO:tensorflow:Done calling model_fn.
# INFO:tensorflow:Starting evaluation at 2019-10-31-14:15:44
# INFO:tensorflow:Graph was finalized.
# INFO:tensorflow:Restoring parameters from ./model7\model.ckpt-1400
# INFO:tensorflow:Running local_init_op.
# INFO:tensorflow:Done running local_init_op.
# INFO:tensorflow:Finished evaluation at 2019-10-31-14:15:44
# INFO:tensorflow:Saving dict for global step 1400: accuracy = 0.8988764, average_loss = 0.2464805, global_step = 1400, loss = 21.936764
# INFO:tensorflow:Saving 'checkpoint_path' summary for global step 1400: ./model7\model.ckpt-1400
# INFO:tensorflow:Loss for final step: 0.7502127.
# *************************************************************************************** step =  13
# INFO:tensorflow:Running training and evaluation locally (non-distributed).
# INFO:tensorflow:Start train and evaluate loop. The evaluate will happen after every checkpoint. Checkpoint frequency is determined based on RunConfig arguments: save_checkpoints_steps None or save_checkpoints_secs 600.
# INFO:tensorflow:Calling model_fn.
# INFO:tensorflow:Done calling model_fn.
# INFO:tensorflow:Create CheckpointSaverHook.
# INFO:tensorflow:Graph was finalized.
# INFO:tensorflow:Restoring parameters from ./model7\model.ckpt-1400
# INFO:tensorflow:Running local_init_op.
# INFO:tensorflow:Done running local_init_op.
# INFO:tensorflow:Saving checkpoints for 1400 into ./model7\model.ckpt.
# INFO:tensorflow:loss = 0.4716509, step = 1401
# INFO:tensorflow:Saving checkpoints for 1500 into ./model7\model.ckpt.
# INFO:tensorflow:Calling model_fn.
# INFO:tensorflow:Done calling model_fn.
# INFO:tensorflow:Starting evaluation at 2019-10-31-14:15:57
# INFO:tensorflow:Graph was finalized.
# INFO:tensorflow:Restoring parameters from ./model7\model.ckpt-1500
# INFO:tensorflow:Running local_init_op.
# INFO:tensorflow:Done running local_init_op.
# INFO:tensorflow:Finished evaluation at 2019-10-31-14:15:58
# INFO:tensorflow:Saving dict for global step 1500: accuracy = 0.8876405, average_loss = 0.25300702, global_step = 1500, loss = 22.517624
# INFO:tensorflow:Saving 'checkpoint_path' summary for global step 1500: ./model7\model.ckpt-1500
# INFO:tensorflow:Loss for final step: 0.76291484.
# *************************************************************************************** step =  14
# INFO:tensorflow:Running training and evaluation locally (non-distributed).
# INFO:tensorflow:Start train and evaluate loop. The evaluate will happen after every checkpoint. Checkpoint frequency is determined based on RunConfig arguments: save_checkpoints_steps None or save_checkpoints_secs 600.
# INFO:tensorflow:Calling model_fn.
# INFO:tensorflow:Done calling model_fn.
# INFO:tensorflow:Create CheckpointSaverHook.
# INFO:tensorflow:Graph was finalized.
# INFO:tensorflow:Restoring parameters from ./model7\model.ckpt-1500
# INFO:tensorflow:Running local_init_op.
# INFO:tensorflow:Done running local_init_op.
# INFO:tensorflow:Saving checkpoints for 1500 into ./model7\model.ckpt.
# INFO:tensorflow:loss = 0.90199053, step = 1501
# INFO:tensorflow:Saving checkpoints for 1600 into ./model7\model.ckpt.
# INFO:tensorflow:Calling model_fn.
# INFO:tensorflow:Done calling model_fn.
# INFO:tensorflow:Starting evaluation at 2019-10-31-14:16:11
# INFO:tensorflow:Graph was finalized.
# INFO:tensorflow:Restoring parameters from ./model7\model.ckpt-1600
# INFO:tensorflow:Running local_init_op.
# INFO:tensorflow:Done running local_init_op.
# INFO:tensorflow:Finished evaluation at 2019-10-31-14:16:11
# INFO:tensorflow:Saving dict for global step 1600: accuracy = 0.89325845, average_loss = 0.25428784, global_step = 1600, loss = 22.631618
# INFO:tensorflow:Saving 'checkpoint_path' summary for global step 1600: ./model7\model.ckpt-1600
# INFO:tensorflow:Loss for final step: 3.0891428.
# *************************************************************************************** step =  15

# %%
input_fn_eval = estimator.inputs.numpy_input_fn( x = {'x':X_v},
                                                shuffle = False)

preds=deep_model.predict(input_fn=input_fn_eval)

# %%
predictions = [p['class_ids'][0] for p in preds]
# Out:
# INFO:tensorflow:Calling model_fn.
# INFO:tensorflow:Done calling model_fn.
# INFO:tensorflow:Graph was finalized.
# INFO:tensorflow:Restoring parameters from ./model7\model.ckpt-1600
# INFO:tensorflow:Running local_init_op.
# INFO:tensorflow:Done running local_init_op.

# %%
pred = np.asarray(predictions)

# %%
for i in range(17,27):
    j = X_v[i].reshape(IMG_W,IMG_H,3)
    print("prediction is:", disease[pred[i]],"\nactually it is:",disease[Y_val[i]])
    plt.imshow(j)
    plt.show()
# Out:
# prediction is: rust
# actually it is: rust
# prediction is: Healthy
# actually it is: Healthy
# prediction is: Mosaic_Virus
# actually it is: Healthy
# prediction is: Mosaic_Virus
# actually it is: Mosaic_Virus
# prediction is: woolyaphids
# actually it is: woolyaphids
# prediction is: Healthy
# actually it is: Healthy
# prediction is: woolyaphids
# actually it is: woolyaphids
# prediction is: woolyaphids
# actually it is: woolyaphids
# prediction is: rust
# actually it is: Healthy
# prediction is: rust
# actually it is: Mosaic_Virus

# %%
f = pred == Y_val
print(len(f))
T = len(f[f == True])
F = len(f[f == False])
print(T, F, T+F)
error = F/(T+F) * 100
print(error)
# Out:
# 178
# 159 19 178
# 10.674157303370785

# %%
saver = tf.train.Saver()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-27-416a2593f909> in <module>()
# ----> 1 saver = tf.train.Saver()
#
# ~\Applictions\Anaconda3\lib\site-packages\tensorflow\python\training\saver.py in __init__(self, var_list, reshape, sharded, max_to_keep, keep_checkpoint_every_n_hours, name, restore_sequentially, saver_def, builder, defer_build, allow_empty, write_version, pad_step_number, save_relative_paths, filename)
#    1092           time.time() + self._keep_checkpoint_every_n_hours * 3600)
#    1093     elif not defer_build:
# -> 1094       self.build()
#    1095     if self.saver_def:
#    1096       self._check_saver_def()
#
# ~\Applictions\Anaconda3\lib\site-packages\tensorflow\python\training\saver.py in build(self)
#    1104     if context.executing_eagerly():
#    1105       raise RuntimeError("Use save/restore instead of build in eager mode.")
# -> 1106     self._build(self._filename, build_save=True, build_restore=True)
#    1107
#    1108   def _build_eager(self, checkpoint_path, build_save, build_restore):
#
# ~\Applictions\Anaconda3\lib\site-packages\tensorflow\python\training\saver.py in _build(self, checkpoint_path, build_save, build_restore)
#    1129           return
#    1130         else:
# -> 1131           raise ValueError("No variables to save")
#    1132       self._is_empty = False
#    1133
#
# ValueError: No variables to save
