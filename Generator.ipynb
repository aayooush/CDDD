# %%
# from google.colab import drive
# drive.mount('/content/drive')

# %%
#CROPP CODE FOR IMAGE TRAINING
import matplotlib.pyplot as plt
import cv2
import numpy as np
import os
# %matplotlib inline
import tensorflow as tf
#np.set_printoptions(threshold=np.inf)
from tensorflow import estimator
tf.reset_default_graph()
from sklearn.model_selection import train_test_split
gs = 0
N_CLASSES = 4   
IMG_W = 200      # for better visibility, go with >180
IMG_H = 200
learning_rate = 0.0001     #slow learning rate for better learning
MODEL = './model3'
NUM_EPOCH = 50
BATCH_SIZE = 16
LOOP = 20                # total no. of epoch = loop * 2*num_epoch
disease ={0:'Healthy', 
          1:'Mosaic_Virus', 
          2:'rust', 
          3:'woolyaphids'}       
def normalize(df):    
    return (df - df.min()) / (df.max() - df.min())
def denormalize(df,norm_data):    
    return (norm_data * (df.max() - df.min())) + df.min()

# %%
def getdata(path):
    ''' returns shuffled array of image file path and labels of corresponding file '''
    woolyaphids = []
    woolyaphids_l= []
    Healthy = []
    Healthy_l = []
    Mosaic_Virus = []
    Mosaic_Virus_l = []
    rust = []
    rust_l = []
    for file in os.listdir(path):
        name=file.split(sep='.')
        if 'healthy' in name[0]:
            Healthy.append(path+file)
            Healthy_l.append(0)
        elif 'mosaic_virus' in name[0]:
            Mosaic_Virus.append(path+file)
            Mosaic_Virus_l.append(1)
        elif 'rust' in name[0]:
            rust.append(path+file)
            rust_l.append(2)
        elif 'woolyaphids' in name[0]:
            woolyaphids.append(path+file)
            woolyaphids_l.append(3)
            
    image_list = np.hstack((Healthy, Mosaic_Virus, rust, woolyaphids ))
    label_list = np.hstack(( Healthy_l, Mosaic_Virus_l, rust_l, woolyaphids_l))
    temp = np.array([image_list, label_list])
    temp = temp.transpose()
    #shuffle whole files and labels respectively
    np.random.shuffle(temp)
    image_list = list(temp[:, 0])
    label_list = list(temp[:, 1])
    label_list = [i for i in label_list]
    print("Healthy plant is: ", len(Healthy))
    print("Rust disease plant is: ", len(rust))
    print("Mosaic_Virus plant is: ", len(Mosaic_Virus))
    print("Woolyaphids plant is: ", len(woolyaphids))
    return image_list, label_list

def process(path):
    '''this function takes file paths from getdata function, 
it reads and processes image file in 4D tensor format i.e.
[batch_size, IMG_Width, IMG_Height, channel]   for grayscale channel = 1, for RGB, channel = 3
'''
    a, train_labels = getdata(path)
    img = []
    batch=len(a)
    for i in range(batch):
        im = cv2.imread(a[i], cv2.IMREAD_COLOR) 
        b,g,r = cv2.split(im)
        image = cv2.merge([r,g,b])
        res = cv2.resize(image,(IMG_W, IMG_H), interpolation = cv2.INTER_CUBIC)
        img.append(res)
        if i%50 == 0: print('Processed {} of {}'.format(i, batch))
    print("finished\nCount of Images is ",len(img),"with input shape",res.shape)
    return np.array(img, dtype=np.int32), np.array(train_labels[:batch], dtype = np.int32)

path = 'TotalData//disease//input//'
X, Y = process(path)
# Out:
# Healthy plant is:  411
# Rust disease plant is:  431
# Mosaic_Virus plant is:  360
# Woolyaphids plant is:  374
# Processed 0 of 1576
# Processed 50 of 1576
# Processed 100 of 1576
# Processed 150 of 1576
# Processed 200 of 1576
# Processed 250 of 1576
# Processed 300 of 1576
# Processed 350 of 1576
# Processed 400 of 1576
# Processed 450 of 1576
# Processed 500 of 1576
# Processed 550 of 1576
# Processed 600 of 1576
# Processed 650 of 1576
# Processed 700 of 1576
# Processed 750 of 1576
# Processed 800 of 1576
# Processed 850 of 1576
# Processed 900 of 1576
# Processed 950 of 1576
# Processed 1000 of 1576
# Processed 1050 of 1576
# Processed 1100 of 1576
# Processed 1150 of 1576
# Processed 1200 of 1576
# Processed 1250 of 1576
# Processed 1300 of 1576
# Processed 1350 of 1576
# Processed 1400 of 1576
# Processed 1450 of 1576
# Processed 1500 of 1576
# Processed 1550 of 1576
# finished
# Count of Images is  1576 with input shape (200, 200, 3)

# %%
# path = 'Data/disease/input/'
# X, Y = process(path)

# %%
pwd
# Out:
# '/Users/aayushsingh/Desktop/CROPP'

# %%
data = []
for i in X:
    data.append(i.reshape(IMG_W*IMG_H*3))
data = np.array(data)

# %%
print('shape of whole data and their labels are as follows',data.shape,'and',Y.shape,"respectively")
# Out:
# shape of whole data and their labels are as follows (1576, 120000) and (1576,) respectively

# %%
for i in range(170, 180):
    j =data[i].reshape(IMG_W,IMG_H,3)
    print("actually it is:",disease[Y[i]])
    plt.imshow(j)
    plt.show()  
#this cell is used to ensure proper labelling of image
# Out:
# actually it is: woolyaphids
# actually it is: rust
# actually it is: Healthy
# actually it is: Healthy
# actually it is: Healthy
# actually it is: rust
# actually it is: Healthy
# actually it is: woolyaphids
# actually it is: Healthy
# actually it is: Mosaic_Virus

# %%
X_train, X_val, Y_train, Y_val = train_test_split(data ,Y, test_size=0.3, random_state=1)

# %%
X_tr = []
for i in X_train:
    X_tr.append(normalize(i))
X_tr = np.array(X_tr)

X_v = []
for i in X_val:
    X_v.append(normalize(i))
X_v = np.array(X_v)

# %%
feat_cols=[tf.feature_column.numeric_column('x', shape=[IMG_H*IMG_W*3])]

# %%
deep_model = tf.estimator.DNNClassifier(feature_columns=feat_cols, 
                                      n_classes=N_CLASSES,
                                      hidden_units=[100, 200, 300,  300, 200, 100, 50], 
                                      activation_fn=tf.nn.relu,
                                      optimizer=tf.train.GradientDescentOptimizer(learning_rate),
                                      model_dir=MODEL)
# Out:
# INFO:tensorflow:Using default config.
# INFO:tensorflow:Using config: {'_model_dir': './model3', '_tf_random_seed': None, '_save_summary_steps': 100, '_save_checkpoints_steps': None, '_save_checkpoints_secs': 600, '_session_config': allow_soft_placement: true
# graph_options {
#   rewrite_options {
#     meta_optimizer_iterations: ONE
#   }
# }
# , '_keep_checkpoint_max': 5, '_keep_checkpoint_every_n_hours': 10000, '_log_step_count_steps': 100, '_train_distribute': None, '_device_fn': None, '_protocol': None, '_eval_distribute': None, '_experimental_distribute': None, '_service': None, '_cluster_spec': <tensorflow.python.training.server_lib.ClusterSpec object at 0x1a3004cf10>, '_task_type': 'worker', '_task_id': 0, '_global_id_in_cluster': 0, '_master': '', '_evaluation_master': '', '_is_chief': True, '_num_ps_replicas': 0, '_num_worker_replicas': 1}

# %%
input_fn = estimator.inputs.numpy_input_fn(x={'x':np.array(X_tr)}, 
                                           y=np.array(Y_train),
                                           shuffle= True,
                                           num_epochs=NUM_EPOCH,
                                           batch_size=BATCH_SIZE)

# %%
input_fn_eval = estimator.inputs.numpy_input_fn(x = {'x':np.array(X_v)},
                                                y = Y_val,
                                                shuffle=False)

# %%
for i in range(LOOP):
    gs = gs + NUM_EPOCH*2
    train_spec = tf.estimator.TrainSpec(input_fn = input_fn, max_steps = gs)
    eval_spec  = tf.estimator.EvalSpec(input_fn = input_fn_eval)
    tf.estimator.train_and_evaluate(deep_model, train_spec, eval_spec)
    print("*************************************************************************************** step = ", i)
# Out:
# INFO:tensorflow:Not using Distribute Coordinator.
# INFO:tensorflow:Running training and evaluation locally (non-distributed).
# INFO:tensorflow:Start train and evaluate loop. The evaluate will happen after every checkpoint. Checkpoint frequency is determined based on RunConfig arguments: save_checkpoints_steps None or save_checkpoints_secs 600.
# INFO:tensorflow:Calling model_fn.
# INFO:tensorflow:Done calling model_fn.
# INFO:tensorflow:Create CheckpointSaverHook.
# INFO:tensorflow:Graph was finalized.
# INFO:tensorflow:Running local_init_op.
# INFO:tensorflow:Done running local_init_op.
# INFO:tensorflow:Saving checkpoints for 0 into ./model3/model.ckpt.
# INFO:tensorflow:loss = 22.350765, step = 1
# INFO:tensorflow:Saving checkpoints for 100 into ./model3/model.ckpt.
# INFO:tensorflow:Calling model_fn.
# INFO:tensorflow:Done calling model_fn.
# INFO:tensorflow:Starting evaluation at 2019-09-26T11:38:30Z
# INFO:tensorflow:Graph was finalized.
# INFO:tensorflow:Restoring parameters from ./model3/model.ckpt-100
# INFO:tensorflow:Running local_init_op.
# INFO:tensorflow:Done running local_init_op.
# INFO:tensorflow:Finished evaluation at 2019-09-26-11:38:36
# INFO:tensorflow:Saving dict for global step 100: accuracy = 0.44820297, average_loss = 1.3378516, global_step = 100, loss = 158.20096
# INFO:tensorflow:Saving 'checkpoint_path' summary for global step 100: ./model3/model.ckpt-100
# INFO:tensorflow:Loss for final step: 21.767426.
# *************************************************************************************** step =  0
# INFO:tensorflow:Not using Distribute Coordinator.
# INFO:tensorflow:Running training and evaluation locally (non-distributed).
# INFO:tensorflow:Start train and evaluate loop. The evaluate will happen after every checkpoint. Checkpoint frequency is determined based on RunConfig arguments: save_checkpoints_steps None or save_checkpoints_secs 600.
# INFO:tensorflow:Calling model_fn.
# INFO:tensorflow:Done calling model_fn.
# INFO:tensorflow:Create CheckpointSaverHook.
# INFO:tensorflow:Graph was finalized.
# INFO:tensorflow:Restoring parameters from ./model3/model.ckpt-100
# INFO:tensorflow:Running local_init_op.
# INFO:tensorflow:Done running local_init_op.
# INFO:tensorflow:Saving checkpoints for 100 into ./model3/model.ckpt.
# INFO:tensorflow:loss = 21.643698, step = 101
# INFO:tensorflow:Saving checkpoints for 200 into ./model3/model.ckpt.
# INFO:tensorflow:Calling model_fn.
# INFO:tensorflow:Done calling model_fn.
# INFO:tensorflow:Starting evaluation at 2019-09-26T11:38:46Z
# INFO:tensorflow:Graph was finalized.
# INFO:tensorflow:Restoring parameters from ./model3/model.ckpt-200
# INFO:tensorflow:Running local_init_op.
# INFO:tensorflow:Done running local_init_op.
# INFO:tensorflow:Finished evaluation at 2019-09-26-11:38:48
# INFO:tensorflow:Saving dict for global step 200: accuracy = 0.30866808, average_loss = 1.2975669, global_step = 200, loss = 153.43729
# INFO:tensorflow:Saving 'checkpoint_path' summary for global step 200: ./model3/model.ckpt-200
# INFO:tensorflow:Loss for final step: 21.238796.
# *************************************************************************************** step =  1
# INFO:tensorflow:Not using Distribute Coordinator.
# INFO:tensorflow:Running training and evaluation locally (non-distributed).
# INFO:tensorflow:Start train and evaluate loop. The evaluate will happen after every checkpoint. Checkpoint frequency is determined based on RunConfig arguments: save_checkpoints_steps None or save_checkpoints_secs 600.
# INFO:tensorflow:Calling model_fn.
# INFO:tensorflow:Done calling model_fn.
# INFO:tensorflow:Create CheckpointSaverHook.
# INFO:tensorflow:Graph was finalized.
# INFO:tensorflow:Restoring parameters from ./model3/model.ckpt-200
# INFO:tensorflow:Running local_init_op.
# INFO:tensorflow:Done running local_init_op.
# INFO:tensorflow:Saving checkpoints for 200 into ./model3/model.ckpt.
# INFO:tensorflow:loss = 19.54519, step = 201
# INFO:tensorflow:Saving checkpoints for 300 into ./model3/model.ckpt.
# INFO:tensorflow:Calling model_fn.
# INFO:tensorflow:Done calling model_fn.
# INFO:tensorflow:Starting evaluation at 2019-09-26T11:38:57Z
# INFO:tensorflow:Graph was finalized.
# INFO:tensorflow:Restoring parameters from ./model3/model.ckpt-300
# INFO:tensorflow:Running local_init_op.
# INFO:tensorflow:Done running local_init_op.
# INFO:tensorflow:Finished evaluation at 2019-09-26-11:39:00
# INFO:tensorflow:Saving dict for global step 300: accuracy = 0.37209302, average_loss = 1.2454566, global_step = 300, loss = 147.27524
# INFO:tensorflow:Saving 'checkpoint_path' summary for global step 300: ./model3/model.ckpt-300
# INFO:tensorflow:Loss for final step: 22.218832.
# *************************************************************************************** step =  2
# INFO:tensorflow:Not using Distribute Coordinator.
# INFO:tensorflow:Running training and evaluation locally (non-distributed).
# INFO:tensorflow:Start train and evaluate loop. The evaluate will happen after every checkpoint. Checkpoint frequency is determined based on RunConfig arguments: save_checkpoints_steps None or save_checkpoints_secs 600.
# INFO:tensorflow:Calling model_fn.
# INFO:tensorflow:Done calling model_fn.
# INFO:tensorflow:Create CheckpointSaverHook.
# INFO:tensorflow:Graph was finalized.
# INFO:tensorflow:Restoring parameters from ./model3/model.ckpt-300
# INFO:tensorflow:Running local_init_op.
# INFO:tensorflow:Done running local_init_op.
# INFO:tensorflow:Saving checkpoints for 300 into ./model3/model.ckpt.
# INFO:tensorflow:loss = 23.593971, step = 301
# INFO:tensorflow:Saving checkpoints for 400 into ./model3/model.ckpt.
# INFO:tensorflow:Calling model_fn.
# INFO:tensorflow:Done calling model_fn.
# INFO:tensorflow:Starting evaluation at 2019-09-26T11:39:08Z
# INFO:tensorflow:Graph was finalized.
# INFO:tensorflow:Restoring parameters from ./model3/model.ckpt-400
# INFO:tensorflow:Running local_init_op.
# INFO:tensorflow:Done running local_init_op.
# INFO:tensorflow:Finished evaluation at 2019-09-26-11:39:10
# INFO:tensorflow:Saving dict for global step 400: accuracy = 0.5983087, average_loss = 1.0782708, global_step = 400, loss = 127.50552
# INFO:tensorflow:Saving 'checkpoint_path' summary for global step 400: ./model3/model.ckpt-400
# INFO:tensorflow:Loss for final step: 18.785189.
# *************************************************************************************** step =  3
# INFO:tensorflow:Not using Distribute Coordinator.
# INFO:tensorflow:Running training and evaluation locally (non-distributed).
# INFO:tensorflow:Start train and evaluate loop. The evaluate will happen after every checkpoint. Checkpoint frequency is determined based on RunConfig arguments: save_checkpoints_steps None or save_checkpoints_secs 600.
# INFO:tensorflow:Calling model_fn.
# INFO:tensorflow:Done calling model_fn.
# INFO:tensorflow:Create CheckpointSaverHook.
# INFO:tensorflow:Graph was finalized.
# INFO:tensorflow:Restoring parameters from ./model3/model.ckpt-400
# INFO:tensorflow:Running local_init_op.
# INFO:tensorflow:Done running local_init_op.
# INFO:tensorflow:Saving checkpoints for 400 into ./model3/model.ckpt.
# INFO:tensorflow:loss = 16.11666, step = 401
# INFO:tensorflow:Saving checkpoints for 500 into ./model3/model.ckpt.
# INFO:tensorflow:Calling model_fn.
# INFO:tensorflow:Done calling model_fn.
# INFO:tensorflow:Starting evaluation at 2019-09-26T11:39:18Z
# INFO:tensorflow:Graph was finalized.
# INFO:tensorflow:Restoring parameters from ./model3/model.ckpt-500
# INFO:tensorflow:Running local_init_op.
# INFO:tensorflow:Done running local_init_op.
# INFO:tensorflow:Finished evaluation at 2019-09-26-11:39:20
# INFO:tensorflow:Saving dict for global step 500: accuracy = 0.53488374, average_loss = 1.1023895, global_step = 500, loss = 130.35756
# INFO:tensorflow:Saving 'checkpoint_path' summary for global step 500: ./model3/model.ckpt-500
# INFO:tensorflow:Loss for final step: 19.723248.
# *************************************************************************************** step =  4
# INFO:tensorflow:Not using Distribute Coordinator.
# INFO:tensorflow:Running training and evaluation locally (non-distributed).
# INFO:tensorflow:Start train and evaluate loop. The evaluate will happen after every checkpoint. Checkpoint frequency is determined based on RunConfig arguments: save_checkpoints_steps None or save_checkpoints_secs 600.
# INFO:tensorflow:Calling model_fn.
# INFO:tensorflow:Done calling model_fn.
# INFO:tensorflow:Create CheckpointSaverHook.
# INFO:tensorflow:Graph was finalized.
# INFO:tensorflow:Restoring parameters from ./model3/model.ckpt-500
# INFO:tensorflow:Running local_init_op.
# INFO:tensorflow:Done running local_init_op.
# INFO:tensorflow:Saving checkpoints for 500 into ./model3/model.ckpt.
# INFO:tensorflow:loss = 19.209639, step = 501
# INFO:tensorflow:Saving checkpoints for 600 into ./model3/model.ckpt.
# INFO:tensorflow:Calling model_fn.
# INFO:tensorflow:Done calling model_fn.
# INFO:tensorflow:Starting evaluation at 2019-09-26T11:39:28Z
# INFO:tensorflow:Graph was finalized.
# INFO:tensorflow:Restoring parameters from ./model3/model.ckpt-600
# INFO:tensorflow:Running local_init_op.
# INFO:tensorflow:Done running local_init_op.
# INFO:tensorflow:Finished evaluation at 2019-09-26-11:39:30
# INFO:tensorflow:Saving dict for global step 600: accuracy = 0.5813953, average_loss = 1.0509007, global_step = 600, loss = 124.26901
# INFO:tensorflow:Saving 'checkpoint_path' summary for global step 600: ./model3/model.ckpt-600
# INFO:tensorflow:Loss for final step: 17.862015.
# *************************************************************************************** step =  5
# INFO:tensorflow:Not using Distribute Coordinator.
# INFO:tensorflow:Running training and evaluation locally (non-distributed).
# INFO:tensorflow:Start train and evaluate loop. The evaluate will happen after every checkpoint. Checkpoint frequency is determined based on RunConfig arguments: save_checkpoints_steps None or save_checkpoints_secs 600.
# INFO:tensorflow:Calling model_fn.
# INFO:tensorflow:Done calling model_fn.
# INFO:tensorflow:Create CheckpointSaverHook.
# INFO:tensorflow:Graph was finalized.
# INFO:tensorflow:Restoring parameters from ./model3/model.ckpt-600
# INFO:tensorflow:Running local_init_op.
# INFO:tensorflow:Done running local_init_op.
# INFO:tensorflow:Saving checkpoints for 600 into ./model3/model.ckpt.
# INFO:tensorflow:loss = 17.095024, step = 601
# INFO:tensorflow:Saving checkpoints for 700 into ./model3/model.ckpt.
# INFO:tensorflow:Calling model_fn.
# INFO:tensorflow:Done calling model_fn.
# INFO:tensorflow:Starting evaluation at 2019-09-26T11:39:38Z
# INFO:tensorflow:Graph was finalized.
# INFO:tensorflow:Restoring parameters from ./model3/model.ckpt-700
# INFO:tensorflow:Running local_init_op.
# INFO:tensorflow:Done running local_init_op.
# INFO:tensorflow:Finished evaluation at 2019-09-26-11:39:40
# INFO:tensorflow:Saving dict for global step 700: accuracy = 0.58773786, average_loss = 1.001872, global_step = 700, loss = 118.47136
# INFO:tensorflow:Saving 'checkpoint_path' summary for global step 700: ./model3/model.ckpt-700
# INFO:tensorflow:Loss for final step: 20.091652.
# *************************************************************************************** step =  6
# INFO:tensorflow:Not using Distribute Coordinator.
# INFO:tensorflow:Running training and evaluation locally (non-distributed).
# INFO:tensorflow:Start train and evaluate loop. The evaluate will happen after every checkpoint. Checkpoint frequency is determined based on RunConfig arguments: save_checkpoints_steps None or save_checkpoints_secs 600.
# INFO:tensorflow:Calling model_fn.
# INFO:tensorflow:Done calling model_fn.
# INFO:tensorflow:Create CheckpointSaverHook.
# INFO:tensorflow:Graph was finalized.
# INFO:tensorflow:Restoring parameters from ./model3/model.ckpt-700
# INFO:tensorflow:Running local_init_op.
# INFO:tensorflow:Done running local_init_op.
# INFO:tensorflow:Saving checkpoints for 700 into ./model3/model.ckpt.
# INFO:tensorflow:loss = 12.897883, step = 701
# INFO:tensorflow:Saving checkpoints for 800 into ./model3/model.ckpt.
# INFO:tensorflow:Calling model_fn.
# INFO:tensorflow:Done calling model_fn.
# INFO:tensorflow:Starting evaluation at 2019-09-26T11:39:49Z
# INFO:tensorflow:Graph was finalized.
# INFO:tensorflow:Restoring parameters from ./model3/model.ckpt-800
# INFO:tensorflow:Running local_init_op.
# INFO:tensorflow:Done running local_init_op.
# INFO:tensorflow:Finished evaluation at 2019-09-26-11:39:51
# INFO:tensorflow:Saving dict for global step 800: accuracy = 0.55813956, average_loss = 1.0539726, global_step = 800, loss = 124.632256
# INFO:tensorflow:Saving 'checkpoint_path' summary for global step 800: ./model3/model.ckpt-800
# INFO:tensorflow:Loss for final step: 14.129818.
# *************************************************************************************** step =  7
# INFO:tensorflow:Not using Distribute Coordinator.
# INFO:tensorflow:Running training and evaluation locally (non-distributed).
# INFO:tensorflow:Start train and evaluate loop. The evaluate will happen after every checkpoint. Checkpoint frequency is determined based on RunConfig arguments: save_checkpoints_steps None or save_checkpoints_secs 600.
# INFO:tensorflow:Calling model_fn.
# INFO:tensorflow:Done calling model_fn.
# INFO:tensorflow:Create CheckpointSaverHook.
# INFO:tensorflow:Graph was finalized.
# INFO:tensorflow:Restoring parameters from ./model3/model.ckpt-800
# INFO:tensorflow:Running local_init_op.
# INFO:tensorflow:Done running local_init_op.
# INFO:tensorflow:Saving checkpoints for 800 into ./model3/model.ckpt.
# INFO:tensorflow:loss = 14.464887, step = 801
# INFO:tensorflow:Saving checkpoints for 900 into ./model3/model.ckpt.
# INFO:tensorflow:Calling model_fn.
# INFO:tensorflow:Done calling model_fn.
# INFO:tensorflow:Starting evaluation at 2019-09-26T11:39:59Z
# INFO:tensorflow:Graph was finalized.
# INFO:tensorflow:Restoring parameters from ./model3/model.ckpt-900
# INFO:tensorflow:Running local_init_op.
# INFO:tensorflow:Done running local_init_op.
# INFO:tensorflow:Finished evaluation at 2019-09-26-11:40:01
# INFO:tensorflow:Saving dict for global step 900: accuracy = 0.55813956, average_loss = 1.0441952, global_step = 900, loss = 123.476074
# INFO:tensorflow:Saving 'checkpoint_path' summary for global step 900: ./model3/model.ckpt-900
# INFO:tensorflow:Loss for final step: 17.827991.
# *************************************************************************************** step =  8
# INFO:tensorflow:Not using Distribute Coordinator.
# INFO:tensorflow:Running training and evaluation locally (non-distributed).
# INFO:tensorflow:Start train and evaluate loop. The evaluate will happen after every checkpoint. Checkpoint frequency is determined based on RunConfig arguments: save_checkpoints_steps None or save_checkpoints_secs 600.
# INFO:tensorflow:Calling model_fn.
# INFO:tensorflow:Done calling model_fn.
# INFO:tensorflow:Create CheckpointSaverHook.
# INFO:tensorflow:Graph was finalized.
# INFO:tensorflow:Restoring parameters from ./model3/model.ckpt-900
# INFO:tensorflow:Running local_init_op.
# INFO:tensorflow:Done running local_init_op.
# INFO:tensorflow:Saving checkpoints for 900 into ./model3/model.ckpt.
# INFO:tensorflow:loss = 11.625723, step = 901
# INFO:tensorflow:Saving checkpoints for 1000 into ./model3/model.ckpt.
# INFO:tensorflow:Calling model_fn.
# INFO:tensorflow:Done calling model_fn.
# INFO:tensorflow:Starting evaluation at 2019-09-26T11:40:09Z
# INFO:tensorflow:Graph was finalized.
# INFO:tensorflow:Restoring parameters from ./model3/model.ckpt-1000
# INFO:tensorflow:Running local_init_op.
# INFO:tensorflow:Done running local_init_op.
# INFO:tensorflow:Finished evaluation at 2019-09-26-11:40:10
# INFO:tensorflow:Saving dict for global step 1000: accuracy = 0.56448203, average_loss = 0.9996325, global_step = 1000, loss = 118.20654
# INFO:tensorflow:Saving 'checkpoint_path' summary for global step 1000: ./model3/model.ckpt-1000
# INFO:tensorflow:Loss for final step: 15.808696.
# *************************************************************************************** step =  9
# INFO:tensorflow:Not using Distribute Coordinator.
# INFO:tensorflow:Running training and evaluation locally (non-distributed).
# INFO:tensorflow:Start train and evaluate loop. The evaluate will happen after every checkpoint. Checkpoint frequency is determined based on RunConfig arguments: save_checkpoints_steps None or save_checkpoints_secs 600.
# INFO:tensorflow:Calling model_fn.
# INFO:tensorflow:Done calling model_fn.
# INFO:tensorflow:Create CheckpointSaverHook.
# INFO:tensorflow:Graph was finalized.
# INFO:tensorflow:Restoring parameters from ./model3/model.ckpt-1000
# INFO:tensorflow:Running local_init_op.
# INFO:tensorflow:Done running local_init_op.
# INFO:tensorflow:Saving checkpoints for 1000 into ./model3/model.ckpt.
# INFO:tensorflow:loss = 13.317914, step = 1001
# INFO:tensorflow:Saving checkpoints for 1100 into ./model3/model.ckpt.
# INFO:tensorflow:Calling model_fn.
# INFO:tensorflow:Done calling model_fn.
# INFO:tensorflow:Starting evaluation at 2019-09-26T11:40:20Z
# INFO:tensorflow:Graph was finalized.
# INFO:tensorflow:Restoring parameters from ./model3/model.ckpt-1100
# INFO:tensorflow:Running local_init_op.
# INFO:tensorflow:Done running local_init_op.
# INFO:tensorflow:Finished evaluation at 2019-09-26-11:40:23
# INFO:tensorflow:Saving dict for global step 1100: accuracy = 0.6448203, average_loss = 0.94189894, global_step = 1100, loss = 111.37955
# INFO:tensorflow:Saving 'checkpoint_path' summary for global step 1100: ./model3/model.ckpt-1100
# INFO:tensorflow:Loss for final step: 13.473108.
# *************************************************************************************** step =  10
# INFO:tensorflow:Not using Distribute Coordinator.
# INFO:tensorflow:Running training and evaluation locally (non-distributed).
# INFO:tensorflow:Start train and evaluate loop. The evaluate will happen after every checkpoint. Checkpoint frequency is determined based on RunConfig arguments: save_checkpoints_steps None or save_checkpoints_secs 600.
# INFO:tensorflow:Calling model_fn.
# INFO:tensorflow:Done calling model_fn.
# INFO:tensorflow:Create CheckpointSaverHook.
# INFO:tensorflow:Graph was finalized.
# INFO:tensorflow:Restoring parameters from ./model3/model.ckpt-1100
# INFO:tensorflow:Running local_init_op.
# INFO:tensorflow:Done running local_init_op.
# INFO:tensorflow:Saving checkpoints for 1100 into ./model3/model.ckpt.
# INFO:tensorflow:loss = 12.800997, step = 1101
# INFO:tensorflow:Saving checkpoints for 1200 into ./model3/model.ckpt.
# INFO:tensorflow:Calling model_fn.
# INFO:tensorflow:Done calling model_fn.
# INFO:tensorflow:Starting evaluation at 2019-09-26T11:40:38Z
# INFO:tensorflow:Graph was finalized.
# INFO:tensorflow:Restoring parameters from ./model3/model.ckpt-1200
# INFO:tensorflow:Running local_init_op.
# INFO:tensorflow:Done running local_init_op.
# INFO:tensorflow:Finished evaluation at 2019-09-26-11:40:40
# INFO:tensorflow:Saving dict for global step 1200: accuracy = 0.4947146, average_loss = 1.1281016, global_step = 1200, loss = 133.39801
# INFO:tensorflow:Saving 'checkpoint_path' summary for global step 1200: ./model3/model.ckpt-1200
# INFO:tensorflow:Loss for final step: 17.07129.
# *************************************************************************************** step =  11
# INFO:tensorflow:Not using Distribute Coordinator.
# INFO:tensorflow:Running training and evaluation locally (non-distributed).
# INFO:tensorflow:Start train and evaluate loop. The evaluate will happen after every checkpoint. Checkpoint frequency is determined based on RunConfig arguments: save_checkpoints_steps None or save_checkpoints_secs 600.
# INFO:tensorflow:Calling model_fn.
# INFO:tensorflow:Done calling model_fn.
# INFO:tensorflow:Create CheckpointSaverHook.
# INFO:tensorflow:Graph was finalized.
# INFO:tensorflow:Restoring parameters from ./model3/model.ckpt-1200
# INFO:tensorflow:Running local_init_op.
# INFO:tensorflow:Done running local_init_op.
# INFO:tensorflow:Saving checkpoints for 1200 into ./model3/model.ckpt.
# INFO:tensorflow:loss = 16.476093, step = 1201
# INFO:tensorflow:Saving checkpoints for 1300 into ./model3/model.ckpt.
# INFO:tensorflow:Calling model_fn.
# INFO:tensorflow:Done calling model_fn.
# INFO:tensorflow:Starting evaluation at 2019-09-26T11:40:50Z
# INFO:tensorflow:Graph was finalized.
# INFO:tensorflow:Restoring parameters from ./model3/model.ckpt-1300
# INFO:tensorflow:Running local_init_op.
# INFO:tensorflow:Done running local_init_op.
# INFO:tensorflow:Finished evaluation at 2019-09-26-11:40:51
# INFO:tensorflow:Saving dict for global step 1300: accuracy = 0.60676533, average_loss = 0.92233616, global_step = 1300, loss = 109.06625
# INFO:tensorflow:Saving 'checkpoint_path' summary for global step 1300: ./model3/model.ckpt-1300
# INFO:tensorflow:Loss for final step: 11.254466.
# *************************************************************************************** step =  12
# INFO:tensorflow:Not using Distribute Coordinator.
# INFO:tensorflow:Running training and evaluation locally (non-distributed).
# INFO:tensorflow:Start train and evaluate loop. The evaluate will happen after every checkpoint. Checkpoint frequency is determined based on RunConfig arguments: save_checkpoints_steps None or save_checkpoints_secs 600.
# INFO:tensorflow:Calling model_fn.
# INFO:tensorflow:Done calling model_fn.
# INFO:tensorflow:Create CheckpointSaverHook.
# INFO:tensorflow:Graph was finalized.
# INFO:tensorflow:Restoring parameters from ./model3/model.ckpt-1300
# INFO:tensorflow:Running local_init_op.
# INFO:tensorflow:Done running local_init_op.
# INFO:tensorflow:Saving checkpoints for 1300 into ./model3/model.ckpt.
# INFO:tensorflow:loss = 11.532209, step = 1301
# INFO:tensorflow:Saving checkpoints for 1400 into ./model3/model.ckpt.
# INFO:tensorflow:Calling model_fn.
# INFO:tensorflow:Done calling model_fn.
# INFO:tensorflow:Starting evaluation at 2019-09-26T11:41:00Z
# INFO:tensorflow:Graph was finalized.
# INFO:tensorflow:Restoring parameters from ./model3/model.ckpt-1400
# INFO:tensorflow:Running local_init_op.
# INFO:tensorflow:Done running local_init_op.
# INFO:tensorflow:Finished evaluation at 2019-09-26-11:41:01
# INFO:tensorflow:Saving dict for global step 1400: accuracy = 0.5687104, average_loss = 0.99810314, global_step = 1400, loss = 118.025696
# INFO:tensorflow:Saving 'checkpoint_path' summary for global step 1400: ./model3/model.ckpt-1400
# INFO:tensorflow:Loss for final step: 12.3237295.
# *************************************************************************************** step =  13
# INFO:tensorflow:Not using Distribute Coordinator.
# INFO:tensorflow:Running training and evaluation locally (non-distributed).
# INFO:tensorflow:Start train and evaluate loop. The evaluate will happen after every checkpoint. Checkpoint frequency is determined based on RunConfig arguments: save_checkpoints_steps None or save_checkpoints_secs 600.
# INFO:tensorflow:Calling model_fn.
# INFO:tensorflow:Done calling model_fn.
# INFO:tensorflow:Create CheckpointSaverHook.
# INFO:tensorflow:Graph was finalized.
# INFO:tensorflow:Restoring parameters from ./model3/model.ckpt-1400
# INFO:tensorflow:Running local_init_op.
# INFO:tensorflow:Done running local_init_op.
# INFO:tensorflow:Saving checkpoints for 1400 into ./model3/model.ckpt.
# INFO:tensorflow:loss = 21.403616, step = 1401
# INFO:tensorflow:Saving checkpoints for 1500 into ./model3/model.ckpt.
# INFO:tensorflow:Calling model_fn.
# INFO:tensorflow:Done calling model_fn.
# INFO:tensorflow:Starting evaluation at 2019-09-26T11:41:10Z
# INFO:tensorflow:Graph was finalized.
# INFO:tensorflow:Restoring parameters from ./model3/model.ckpt-1500
# INFO:tensorflow:Running local_init_op.
# INFO:tensorflow:Done running local_init_op.
# INFO:tensorflow:Finished evaluation at 2019-09-26-11:41:12
# INFO:tensorflow:Saving dict for global step 1500: accuracy = 0.56236786, average_loss = 0.99194515, global_step = 1500, loss = 117.297516
# INFO:tensorflow:Saving 'checkpoint_path' summary for global step 1500: ./model3/model.ckpt-1500
# INFO:tensorflow:Loss for final step: 13.167425.
# *************************************************************************************** step =  14
# INFO:tensorflow:Not using Distribute Coordinator.
# INFO:tensorflow:Running training and evaluation locally (non-distributed).
# INFO:tensorflow:Start train and evaluate loop. The evaluate will happen after every checkpoint. Checkpoint frequency is determined based on RunConfig arguments: save_checkpoints_steps None or save_checkpoints_secs 600.
# INFO:tensorflow:Calling model_fn.
# INFO:tensorflow:Done calling model_fn.
# INFO:tensorflow:Create CheckpointSaverHook.
# INFO:tensorflow:Graph was finalized.
# INFO:tensorflow:Restoring parameters from ./model3/model.ckpt-1500
# INFO:tensorflow:Running local_init_op.
# INFO:tensorflow:Done running local_init_op.
# INFO:tensorflow:Saving checkpoints for 1500 into ./model3/model.ckpt.
# INFO:tensorflow:loss = 14.475423, step = 1501
# INFO:tensorflow:Saving checkpoints for 1600 into ./model3/model.ckpt.
# INFO:tensorflow:Calling model_fn.
# INFO:tensorflow:Done calling model_fn.
# INFO:tensorflow:Starting evaluation at 2019-09-26T11:41:21Z
# INFO:tensorflow:Graph was finalized.
# INFO:tensorflow:Restoring parameters from ./model3/model.ckpt-1600
# INFO:tensorflow:Running local_init_op.
# INFO:tensorflow:Done running local_init_op.
# INFO:tensorflow:Finished evaluation at 2019-09-26-11:41:23
# INFO:tensorflow:Saving dict for global step 1600: accuracy = 0.5792812, average_loss = 0.9833704, global_step = 1600, loss = 116.283554
# INFO:tensorflow:Saving 'checkpoint_path' summary for global step 1600: ./model3/model.ckpt-1600
# INFO:tensorflow:Loss for final step: 16.038517.
# *************************************************************************************** step =  15
# INFO:tensorflow:Not using Distribute Coordinator.
# INFO:tensorflow:Running training and evaluation locally (non-distributed).
# INFO:tensorflow:Start train and evaluate loop. The evaluate will happen after every checkpoint. Checkpoint frequency is determined based on RunConfig arguments: save_checkpoints_steps None or save_checkpoints_secs 600.
# INFO:tensorflow:Calling model_fn.
# INFO:tensorflow:Done calling model_fn.
# INFO:tensorflow:Create CheckpointSaverHook.
# INFO:tensorflow:Graph was finalized.
# INFO:tensorflow:Restoring parameters from ./model3/model.ckpt-1600
# INFO:tensorflow:Running local_init_op.
# INFO:tensorflow:Done running local_init_op.
# INFO:tensorflow:Saving checkpoints for 1600 into ./model3/model.ckpt.
# INFO:tensorflow:loss = 11.951397, step = 1601
# INFO:tensorflow:Saving checkpoints for 1700 into ./model3/model.ckpt.
# INFO:tensorflow:Calling model_fn.
# INFO:tensorflow:Done calling model_fn.
# INFO:tensorflow:Starting evaluation at 2019-09-26T11:41:32Z
# INFO:tensorflow:Graph was finalized.
# INFO:tensorflow:Restoring parameters from ./model3/model.ckpt-1700
# INFO:tensorflow:Running local_init_op.
# INFO:tensorflow:Done running local_init_op.
# INFO:tensorflow:Finished evaluation at 2019-09-26-11:41:33
# INFO:tensorflow:Saving dict for global step 1700: accuracy = 0.5792812, average_loss = 1.0547378, global_step = 1700, loss = 124.72275
# INFO:tensorflow:Saving 'checkpoint_path' summary for global step 1700: ./model3/model.ckpt-1700
# INFO:tensorflow:Loss for final step: 14.986825.
# *************************************************************************************** step =  16
# INFO:tensorflow:Not using Distribute Coordinator.
# INFO:tensorflow:Running training and evaluation locally (non-distributed).
# INFO:tensorflow:Start train and evaluate loop. The evaluate will happen after every checkpoint. Checkpoint frequency is determined based on RunConfig arguments: save_checkpoints_steps None or save_checkpoints_secs 600.
# INFO:tensorflow:Calling model_fn.
# INFO:tensorflow:Done calling model_fn.
# INFO:tensorflow:Create CheckpointSaverHook.
# INFO:tensorflow:Graph was finalized.
# INFO:tensorflow:Restoring parameters from ./model3/model.ckpt-1700
# INFO:tensorflow:Running local_init_op.
# INFO:tensorflow:Done running local_init_op.
# INFO:tensorflow:Saving checkpoints for 1700 into ./model3/model.ckpt.
# INFO:tensorflow:loss = 10.676212, step = 1701
# INFO:tensorflow:Saving checkpoints for 1800 into ./model3/model.ckpt.
# INFO:tensorflow:Calling model_fn.
# INFO:tensorflow:Done calling model_fn.
# INFO:tensorflow:Starting evaluation at 2019-09-26T11:41:43Z
# INFO:tensorflow:Graph was finalized.
# INFO:tensorflow:Restoring parameters from ./model3/model.ckpt-1800
# INFO:tensorflow:Running local_init_op.
# INFO:tensorflow:Done running local_init_op.
# INFO:tensorflow:Finished evaluation at 2019-09-26-11:41:45
# INFO:tensorflow:Saving dict for global step 1800: accuracy = 0.5687104, average_loss = 1.0124823, global_step = 1800, loss = 119.72603
# INFO:tensorflow:Saving 'checkpoint_path' summary for global step 1800: ./model3/model.ckpt-1800
# INFO:tensorflow:Loss for final step: 15.177516.
# *************************************************************************************** step =  17
# INFO:tensorflow:Not using Distribute Coordinator.
# INFO:tensorflow:Running training and evaluation locally (non-distributed).
# INFO:tensorflow:Start train and evaluate loop. The evaluate will happen after every checkpoint. Checkpoint frequency is determined based on RunConfig arguments: save_checkpoints_steps None or save_checkpoints_secs 600.
# INFO:tensorflow:Calling model_fn.
# INFO:tensorflow:Done calling model_fn.
# INFO:tensorflow:Create CheckpointSaverHook.
# INFO:tensorflow:Graph was finalized.
# INFO:tensorflow:Restoring parameters from ./model3/model.ckpt-1800
# INFO:tensorflow:Running local_init_op.
# INFO:tensorflow:Done running local_init_op.
# INFO:tensorflow:Saving checkpoints for 1800 into ./model3/model.ckpt.
# INFO:tensorflow:loss = 10.726492, step = 1801
# INFO:tensorflow:Saving checkpoints for 1900 into ./model3/model.ckpt.
# INFO:tensorflow:Calling model_fn.
# INFO:tensorflow:Done calling model_fn.
# INFO:tensorflow:Starting evaluation at 2019-09-26T11:41:53Z
# INFO:tensorflow:Graph was finalized.
# INFO:tensorflow:Restoring parameters from ./model3/model.ckpt-1900
# INFO:tensorflow:Running local_init_op.
# INFO:tensorflow:Done running local_init_op.
# INFO:tensorflow:Finished evaluation at 2019-09-26-11:41:54
# INFO:tensorflow:Saving dict for global step 1900: accuracy = 0.53911203, average_loss = 1.0546244, global_step = 1900, loss = 124.709335
# INFO:tensorflow:Saving 'checkpoint_path' summary for global step 1900: ./model3/model.ckpt-1900
# INFO:tensorflow:Loss for final step: 14.508612.
# *************************************************************************************** step =  18
# INFO:tensorflow:Not using Distribute Coordinator.
# INFO:tensorflow:Running training and evaluation locally (non-distributed).
# INFO:tensorflow:Start train and evaluate loop. The evaluate will happen after every checkpoint. Checkpoint frequency is determined based on RunConfig arguments: save_checkpoints_steps None or save_checkpoints_secs 600.
# INFO:tensorflow:Calling model_fn.
# INFO:tensorflow:Done calling model_fn.
# INFO:tensorflow:Create CheckpointSaverHook.
# INFO:tensorflow:Graph was finalized.
# INFO:tensorflow:Restoring parameters from ./model3/model.ckpt-1900
# INFO:tensorflow:Running local_init_op.
# INFO:tensorflow:Done running local_init_op.
# INFO:tensorflow:Saving checkpoints for 1900 into ./model3/model.ckpt.
# INFO:tensorflow:loss = 14.55826, step = 1901
# INFO:tensorflow:Saving checkpoints for 2000 into ./model3/model.ckpt.
# INFO:tensorflow:Calling model_fn.
# INFO:tensorflow:Done calling model_fn.
# INFO:tensorflow:Starting evaluation at 2019-09-26T11:42:02Z
# INFO:tensorflow:Graph was finalized.
# INFO:tensorflow:Restoring parameters from ./model3/model.ckpt-2000
# INFO:tensorflow:Running local_init_op.
# INFO:tensorflow:Done running local_init_op.
# INFO:tensorflow:Finished evaluation at 2019-09-26-11:42:04
# INFO:tensorflow:Saving dict for global step 2000: accuracy = 0.6215645, average_loss = 0.9252992, global_step = 2000, loss = 109.41663
# INFO:tensorflow:Saving 'checkpoint_path' summary for global step 2000: ./model3/model.ckpt-2000
# INFO:tensorflow:Loss for final step: 13.658897.
# *************************************************************************************** step =  19

# %%
input_fn_eval = estimator.inputs.numpy_input_fn( x = {'x':X_v},
                                                shuffle = False)

preds=deep_model.predict(input_fn=input_fn_eval)

# %%
predictions = [p['class_ids'][0] for p in preds]
# Out:
# INFO:tensorflow:Calling model_fn.
# INFO:tensorflow:Done calling model_fn.
# INFO:tensorflow:Graph was finalized.
# INFO:tensorflow:Restoring parameters from ./model3/model.ckpt-2000
# INFO:tensorflow:Running local_init_op.
# INFO:tensorflow:Done running local_init_op.

# %%
pred = np.asarray(predictions)

# %%
for i in range(17,27):
    j = X_v[i].reshape(IMG_W,IMG_H,3)
    print("prediction is:", disease[pred[i]],"\nactually it is:",disease[Y_val[i]])
    plt.imshow(j)
    plt.show()
# Out:
# prediction is: rust
# actually it is: rust
# prediction is: Healthy
# actually it is: Healthy
# prediction is: Healthy
# actually it is: Mosaic_Virus
# prediction is: woolyaphids
# actually it is: woolyaphids
# prediction is: rust
# actually it is: woolyaphids
# prediction is: rust
# actually it is: Mosaic_Virus
# prediction is: rust
# actually it is: rust
# prediction is: Healthy
# actually it is: Healthy
# prediction is: woolyaphids
# actually it is: woolyaphids
# prediction is: Mosaic_Virus
# actually it is: rust

# %%
f = pred == Y_val
print(len(f))
T = len(f[f == True])
F = len(f[f == False])
print(T, F, T+F)
error = F/(T+F) * 100
print(error)
# Out:
# 473
# 294 179 473
# 37.84355179704017
