# %%
# from google.colab import drive
# drive.mount('/content/drive')

# %%
from pathlib import Path
import numpy as np
import cv2
import os
import h5py
import glob
import matplotlib.pyplot as plt
from sklearn.model_selection import train_test_split
from sklearn.metrics import classification_report, accuracy_score
from sklearn.ensemble import RandomForestClassifier
from sklearn.utils import Bunch

import skimage
from skimage.io import imread
from skimage.transform import resize

# %%
def load_image_files(container_path, dimension=(128, 128)):
    image_dir = Path(container_path)
    folders = [directory for directory in image_dir.iterdir() if directory.is_dir()]
    categories = [fo.name for fo in folders]

    images = []
    flat_data = []
    target = []
    for i, direc in enumerate(folders):
        for file in direc.iterdir():
            print(file)
            img = skimage.io.imread(file)
            img_resized = resize(img, dimension, anti_aliasing=True, mode='reflect')
            flat_data.append(img_resized.flatten()) 
            images.append(img_resized)
            target.append(i)
    flat_data = np.array(flat_data)
    target = np.array(target)
    images = np.array(images)

    return Bunch(data=flat_data,
                 target=target,
                 target_names=categories,
                 images=images)

# %%
basedir = "../CNN_Data/Training"
image_dataset = load_image_files(basedir)
X_train, X_test, y_train, y_test = train_test_split(image_dataset.data, image_dataset.target, test_size=0.3,random_state=42)
# Out:
# ../CNN_Data/Training/Healthy/healthy1212.jpg
# ../CNN_Data/Training/Healthy/healthy137.jpg
# ../CNN_Data/Training/Healthy/healthy136.jpg
# ../CNN_Data/Training/Healthy/healthy1039.jpg
# ../CNN_Data/Training/Healthy/healthy1211.jpg
# ../CNN_Data/Training/Healthy/healthy1166.jpg
# ../CNN_Data/Training/Healthy/healthy1006.jpg
# ../CNN_Data/Training/Healthy/healthy1210.jpg
# ../CNN_Data/Training/Healthy/healthy1016.jpg
# ../CNN_Data/Training/Healthy/healthy1161.jpg
# ../CNN_Data/Training/Healthy/healthy133.jpg
# ../CNN_Data/Training/Healthy/healthy1014.jpg
# ../CNN_Data/Training/Healthy/healthy1202.jpg
# ../CNN_Data/Training/Healthy/healthy1271.jpg
# ../CNN_Data/Training/Healthy/healthy95.jpg
# ../CNN_Data/Training/Healthy/healthy1073.jpg
# ../CNN_Data/Training/Healthy/healthy183.jpg
# ../CNN_Data/Training/Healthy/healthy197.jpg
# ../CNN_Data/Training/Healthy/healthy140.jpg
# ../CNN_Data/Training/Healthy/healthy141.jpg
# ../CNN_Data/Training/Healthy/healthy196.jpg
# ../CNN_Data/Training/Healthy/healthy182.jpg
# ../CNN_Data/Training/Healthy/healthy94.jpg
# ../CNN_Data/Training/Healthy/healthy237.jpg
# ../CNN_Data/Training/Healthy/healthy1272.jpg
# ../CNN_Data/Training/Healthy/healthy209.jpg
# ../CNN_Data/Training/Healthy/healthy1070.jpg
# ../CNN_Data/Training/Healthy/healthy235.jpg
# ../CNN_Data/Training/Healthy/healthy96.jpg
# ../CNN_Data/Training/Healthy/healthy194.jpg
# ../CNN_Data/Training/Healthy/healthy180.jpg
# ../CNN_Data/Training/Healthy/healthy143.jpg
# ../CNN_Data/Training/Healthy/healthy181.jpg
# ../CNN_Data/Training/Healthy/healthy195.jpg
# ../CNN_Data/Training/Healthy/healthy234.jpg
# ../CNN_Data/Training/Healthy/healthy97.jpg
# ../CNN_Data/Training/Healthy/healthy220.jpg
# ../CNN_Data/Training/Healthy/healthy208.jpg
# ../CNN_Data/Training/Healthy/healthy1277.jpg
# ../CNN_Data/Training/Healthy/healthy93.jpg
# ../CNN_Data/Training/Healthy/healthy230.jpg
# ../CNN_Data/Training/Healthy/healthy218.jpg
# ../CNN_Data/Training/Rust/rust114.jpg
# ../CNN_Data/Training/Rust/rust1571.jpg
# ../CNN_Data/Training/Rust/rust81.jpg
# ../CNN_Data/Training/Rust/rust95.jpg
# ../CNN_Data/Training/Rust/rust1607.jpg
# ../CNN_Data/Training/Rust/rust94.jpg
# ../CNN_Data/Training/Rust/rust80.jpg
# ../CNN_Data/Training/Rust/rust57.jpg
# ../CNN_Data/Training/Rust/rust908.jpg
# ../CNN_Data/Training/Rust/rust101.jpg
# ../CNN_Data/Training/Rust/rust1766.jpg
# ../CNN_Data/Training/Rust/rust139.jpg
# ../CNN_Data/Training/Rust/rust105.jpg
# ../CNN_Data/Training/Rust/rust111.jpg
# ../CNN_Data/Training/Rust/rust47.jpg
# ../CNN_Data/Training/Rust/rust53.jpg
# ../CNN_Data/Training/Rust/rust84.jpg
# ../CNN_Data/Training/Rust/rust90.jpg
# ../CNN_Data/Training/Rust/rust91.jpg
# ../CNN_Data/Training/Rust/rust85.jpg
# ../CNN_Data/Training/Rust/rust1398.jpg
# ../CNN_Data/Training/Rust/rust104.jpg
# ../CNN_Data/Training/Rust/rust138.jpg
# ../CNN_Data/Training/Rust/rust1749.jpg
# ../CNN_Data/Training/Rust/rust112.jpg
# ../CNN_Data/Training/Rust/rust93.jpg
# ../CNN_Data/Training/Rust/rust86.jpg
# ../CNN_Data/Training/Rust/rust92.jpg
# ../CNN_Data/Training/Rust/rust79.jpg
# ../CNN_Data/Training/Rust/rust113.jpg
# ../CNN_Data/Training/Rust/rust1204.jpg
# ../CNN_Data/Training/Rust/rust174.jpg
# ../CNN_Data/Training/Rust/rust148.jpg
# ../CNN_Data/Training/Rust/rust203.jpg
# ../CNN_Data/Training/Rust/rust954.jpg
# ../CNN_Data/Training/Rust/rust149.jpg
# ../CNN_Data/Training/Rust/rust175.jpg
# ../CNN_Data/Training/Rust/rust163.jpg
# ../CNN_Data/Training/Rust/rust956.jpg
# ../CNN_Data/Training/Rust/rust201.jpg
# ../CNN_Data/Training/Rust/rust1116.jpg
# ../CNN_Data/Training/Rust/rust166.jpg
# ../CNN_Data/Training/Rust/rust204.jpg
# ../CNN_Data/Training/Rust/rust205.jpg
# ../CNN_Data/Training/Rust/rust167.jpg
# ../CNN_Data/Training/Rust/rust1104.jpg
# ../CNN_Data/Training/Rust/rust992.jpg
# ../CNN_Data/Training/Rust/rust170.jpg
# ../CNN_Data/Training/Rust/rust158.jpg
# ../CNN_Data/Training/Rust/rust155.jpg
# ../CNN_Data/Training/Rust/rust141.jpg
# ../CNN_Data/Training/Rust/rust140.jpg
# ../CNN_Data/Training/Rust/rust154.jpg
# ../CNN_Data/Training/Rust/rust142.jpg
# ../CNN_Data/Training/Rust/rust156.jpg
# ../CNN_Data/Training/Rust/rust1862.jpg
# ../CNN_Data/Training/Rust/rust157.jpg
# ../CNN_Data/Training/Rust/rust143.jpg
# ../CNN_Data/Training/Rust/rust194.jpg
# ../CNN_Data/Training/Rust/rust147.jpg
# ../CNN_Data/Training/Rust/rust1640.jpg
# ../CNN_Data/Training/Rust/rust1133.jpg
# ../CNN_Data/Training/Rust/rust146.jpg
# ../CNN_Data/Training/Rust/rust193.jpg
# ../CNN_Data/Training/Rust/rust150.jpg
# ../CNN_Data/Training/Rust/rust144.jpg
# ../CNN_Data/Training/Rust/rust959.jpg
# ../CNN_Data/Training/Rust/rust1246.jpg
# ../CNN_Data/Training/Rust/rust122.jpg
# ../CNN_Data/Training/Rust/rust1630.jpg
# ../CNN_Data/Training/Rust/rust1234.jpg
# ../CNN_Data/Training/Rust/rust123.jpg
# ../CNN_Data/Training/Rust/rust137.jpg
# ../CNN_Data/Training/Rust/rust135.jpg
# ../CNN_Data/Training/Rust/rust109.jpg
# ../CNN_Data/Training/Rust/rust134.jpg
# ../CNN_Data/Training/Rust/rust124.jpg
# ../CNN_Data/Training/Rust/rust72.jpg
# ../CNN_Data/Training/Rust/rust99.jpg
# ../CNN_Data/Training/Rust/rust1150.jpg
# ../CNN_Data/Training/Rust/rust98.jpg
# ../CNN_Data/Training/Rust/rust125.jpg
# ../CNN_Data/Training/Rust/rust59.jpg
# ../CNN_Data/Training/Rust/rust126.jpg
# ../CNN_Data/Training/Rust/rust1741.jpg

# %%
clf  = RandomForestClassifier(n_estimators=100)
clf.fit(X_train, y_train)

y_pred = clf.predict(X_test)
print(classification_report(y_test,y_pred))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.83      0.85      0.84        46
#            1       0.63      0.68      0.66        28
#            2       0.83      0.96      0.89        26
#            3       0.87      0.67      0.75        30
#
#     accuracy                           0.79       130
#    macro avg       0.79      0.79      0.79       130
# weighted avg       0.80      0.79      0.79       130

# %%
print(accuracy_score(y_test, y_pred))
# Out:
# 0.7923076923076923

# %%
def load_image_file(file, dimension=(128, 128)):

    images = []
    flat_data = []
    target = []
 
    img = skimage.io.imread(file)
    img_resized = resize(img, dimension, anti_aliasing=True, mode='reflect')
    flat_data.append(img_resized.flatten()) 

    flat_data = np.array(flat_data)

    return Bunch(data=flat_data)

# %%
test_path = "../CNN_Data/Validation"

fixed_size = (128,128)
# loop through the test images
#for file in glob.glob(test_path + "/*.jpg"):
train_labels = ['Zero', 'One', 'Two', 'Three']
for dirs in os.listdir(test_path): 
    path =  test_path + "/" + dirs
    for img in os.listdir(path):  
        file = test_path + "/" + dirs + '/' + img
        print(file)
        
        # read the image
        image = cv2.imread(file)

        # resize the image
        image = cv2.resize(image, fixed_size)

        # Global Feature extraction
        x = load_image_file(file)

        # predict label of test image
        prediction = clf.predict(x.data)[0]


        # show predicted label on image
        cv2.putText(image, train_labels[prediction], (20,30), cv2.FONT_HERSHEY_SIMPLEX, 1.0, (0,255,255), 3)

        # display the output image
        plt.imshow(cv2.cvtColor(image, cv2.COLOR_BGR2RGB))
        plt.show()
#         plt.savefig('/content/images/'+img)

# %%
# Saving Model
from sklearn.externals import joblib
filename = 'RF_SKLEARN.sav'
joblib.dump(clf, filename)
# Out:
# /Users/aayushsingh/anaconda3/lib/python3.7/site-packages/sklearn/externals/joblib/__init__.py:15: DeprecationWarning: sklearn.externals.joblib is deprecated in 0.21 and will be removed in 0.23. Please import this functionality directly from joblib, which can be installed with: pip install joblib. If this warning is raised when loading pickled models, you may need to re-serialize those models with scikit-learn 0.21+.
#   warnings.warn(msg, category=DeprecationWarning)
# ['RF_SKLEARN.sav']

# %%
# Loading Model 
from sklearn.externals import joblib
filename = 'SVM_SKLEARN.sav'
loaded_model = joblib.load(filename)
result = loaded_model.score(X_test, y_test)
print(result)

# %%
# Loading Model to Predict
from sklearn.externals import joblib

label_output = ['Healthy', 'Rust', "Mosaic_Virus", "Wooly Aphids"]

def load_image_file(file, dimension=(128, 128)):

    images = []
    flat_data = []
    target = []
 
    img = skimage.io.imread(file)
    img_resized = resize(img, dimension, anti_aliasing=True, mode='reflect')
    flat_data.append(img_resized.flatten()) 

    flat_data = np.array(flat_data)

    return Bunch(data=flat_data,)

filename = 'RF_SKLEARN.sav'
loaded_model = joblib.load(filename)

image = 'TestImage.jpg'
input_image = load_image_file(image)
result = loaded_model.predict(input_image.data)[0]
print(label_output[result])
# Out:
# Healthy
